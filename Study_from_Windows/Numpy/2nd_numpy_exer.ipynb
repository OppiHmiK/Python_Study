# %%
# -*- coding : utf-8 -*-
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set() # NOTE : 플롯 스타일 설정

# %%
mean = [0, 0]
cov = [[1, 2], [2, 5]]

x = np.random.multivariate_normal(mean, cov, 100)
x.shape
# Out:
# (100, 2)

# %%
plt.scatter(x[:,0], x[:,1])

# %%
indices = np.random.choice(x.shape[0], 20, replace = False)
print(indices) 
# NOTE : 0 ~ 99 중 20개를 중복되지 않게 추출

selection = x[indices]
# NOTE : 여기서 팬시 인덱싱 사용
# Out:
# [72 28 82 85 78 88 67 13 94 45 68 57 53 93 84 26 73 91 24 40]

# %%
plt.scatter(x[:,0], x[:,1], alpha = 0.3)
plt.scatter(selection[:,0], selection[:, 1], facecolor='none', s=200)
